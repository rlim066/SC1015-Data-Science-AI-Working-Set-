# %% [markdown]
# # Data Extraction & Cleaning

# %% [markdown]
# ## Data Sets used
#
#
# 1. Movie Data from 1914 to 2021 (Moviedata2021.csv)
#
# Source: Kaggle https://www.kaggle.com/code/ruchi798/movies-and-tv-shows-eda/data?select=MoviesOnStreamingPlatforms_updated.csv
# 2. Movie Data from 1902 to 2020 (Moviedata2020.csv)
#
# Source Kaggle https://www.kaggle.com/code/armintalic/quality-and-quantity-of-streaming-services-content/data?select=MoviesOnStreamingPlatforms_updated.csv

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Extracting & Comparing data sets

# %%
Moviedata2021 = pd.read_csv('Moviedata2021.csv')
Moviedata2021.head()
# Out:
#    Unnamed: 0  ID                                     Title  Year  Age  \
# 0           0   1                              The Irishman  2019  18+
# 1           1   2                                    Dangal  2016   7+
# 2           2   3  David Attenborough: A Life on Our Planet  2020   7+
# 3           3   4         Lagaan: Once Upon a Time in India  2001   7+
# 4           4   5                                      Roma  2018  18+
#
#      IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0  7.8/10          98/100        1     0            0        0     0
# 1  8.4/10          97/100        1     0            0        0     0
# 2  9.0/10          95/100        1     0            0        0     0
# 3  8.1/10          94/100        1     0            0        0     0
# 4  7.7/10          94/100        1     0            0        0     0
#
#                                            Directors  \
# 0                                    Martin Scorsese
# ...

# %% [markdown]
# ### Data Information
#
# IMDb Score is in x.x/10 format
# Rotten Tomatoes Score is in xxx/100 format

# %%
Moviedata2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9515 non-null   int64
#  1   ID               9515 non-null   int64
#  2   Title            9515 non-null   object
#  3   Year             9515 non-null   int64
#  4   Age              5338 non-null   object
#  5   IMDb             9309 non-null   object
#  6   Rotten Tomatoes  9508 non-null   object
#  7   Netflix          9515 non-null   int64
#  8   Hulu             9515 non-null   int64
#  9   Prime Video      9515 non-null   int64
#  10  Disney+          9515 non-null   int64
#  11  Type             9515 non-null   int64
#  12  Directors        9104 non-null   object
#  13  Genres           9399 non-null   object
#  14  Country          9261 non-null   object
#  15  Language         9202 non-null   object
#  16  Runtime          9196 non-null   float64
# ...

# %%
Moviedata2020 = pd.read_csv('Moviedata2020.csv')
Moviedata2020.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
Moviedata2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %% [markdown]
# ### Data Information
#
# IMDb Score is in float format
# Rotten Tomatoes Score is in percentage format

# %% [markdown]
# ## Data Combination
#
# Combine our data sets using excel copy by copying all the rows from 2021 into 2020 csv. Resultant csv file is MoviesCombined.csv

# %%
MoviesCombined = pd.read_csv('MoviesCombined.csv')
MoviesCombined.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age IMDb  \
# 0           0   1                       Inception  2010  13+  8.8
# 1           1   2                      The Matrix  1999  18+  8.7
# 2           2   3          Avengers: Infinity War  2018  13+  8.5
# 3           3   4              Back to the Future  1985   7+  8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+  8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
MoviesCombined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26259 entries, 0 to 26258
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       26259 non-null  int64
#  1   ID               26259 non-null  int64
#  2   Title            26259 non-null  object
#  3   Year             26259 non-null  int64
#  4   Age              12692 non-null  object
#  5   IMDb             25482 non-null  object
#  6   Rotten Tomatoes  14666 non-null  object
#  7   Netflix          26259 non-null  int64
#  8   Hulu             26259 non-null  int64
#  9   Prime Video      26259 non-null  int64
#  10  Disney+          26259 non-null  int64
#  11  Type             26259 non-null  int64
#  12  Directors        25122 non-null  object
#  13  Genres           25868 non-null  object
#  14  Country          25570 non-null  object
#  15  Language         25347 non-null  object
#  16  Runtime          25348 non-null  float64
# ...

# %% [markdown]
# ## Data Cleaning & Resolving Format Differences
#
# Our Data Cleaning was done mainly in excel
# Cleaning for respective Columns
#
# ### Changes/Additions:
# IMDb Column was changed to float format
# Rotten Column was changed to float format
# Availability Score Column was added to denote the Total Number of Platforms a movie was available on
# Directors, Genres, Country and Language Columns were changed to only include the first Director, Genre, Country & Language in each cell
# Created Age of Movie Column
# Re-ordered ID Column from 1-5556
#
# ### Removals:
# Unnecessary Columns were removed in Excel including:
# Year
# Netflix
# Hulu
# Prime Video
# Disney+
#
# Rows with rottem tomatoe scores of 0 using filter function on excel
#
#
# ### File Information
# New File "Movies-Excel-Clean.csv" was created

# %%
ExcelClean = pd.read_csv("Movies-Excel-Clean.csv")
ExcelClean.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age of Movie  \
# 0           0   1                       Inception  2010            12
# 1           1   2                      The Matrix  1999            23
# 2           2   3          Avengers: Infinity War  2018             4
# 3           3   4              Back to the Future  1985            37
# 4           4   5  The Good, the Bad and the Ugly  1966            56
#
#   Age Category  IMDb  Rotten  Netflix  Hulu  Prime Video  Disney+  \
# 0          13+   8.8    87.0        1     0            0        0
# 1          18+   8.7    87.0        1     0            0        0
# 2          13+   8.5    84.0        1     0            0        0
# 3           7+   8.5    96.0        1     0            0        0
# 4          18+   8.8    97.0        1     0            1        0
#
#    Availability          Directors     Genres        Country Language  Runtime
# ...

# %%
ExcelClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20983 entries, 0 to 20982
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    20983 non-null  int64
#  1   ID            20983 non-null  int64
#  2   Title         20983 non-null  object
#  3   Year          20983 non-null  int64
#  4   Age of Movie  20983 non-null  int64
#  5   Age Category  9739 non-null   object
#  6   IMDb          20296 non-null  float64
#  7   Rotten        20979 non-null  float64
#  8   Netflix       20983 non-null  int64
#  9   Hulu          20983 non-null  int64
#  10  Prime Video   20983 non-null  int64
#  11  Disney+       20983 non-null  int64
#  12  Availability  20983 non-null  int64
#  13  Directors     20039 non-null  object
#  14  Genres        20639 non-null  object
#  15  Country       20419 non-null  object
#  16  Language      20224 non-null  object
#  17  Runtime       20217 non-null  float64
# ...

# %% [markdown]
# ## Data Cleaning in Python
#
# ### Removals
# Rows with NAN Values were dropped

# %%
df1 = ExcelClean.copy()
df1 = df1.dropna()
df1.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age of Movie  \
# 0           0   1                       Inception  2010            12
# 1           1   2                      The Matrix  1999            23
# 2           2   3          Avengers: Infinity War  2018             4
# 3           3   4              Back to the Future  1985            37
# 4           4   5  The Good, the Bad and the Ugly  1966            56
#
#   Age Category  IMDb  Rotten  Netflix  Hulu  Prime Video  Disney+  \
# 0          13+   8.8    87.0        1     0            0        0
# 1          18+   8.7    87.0        1     0            0        0
# 2          13+   8.5    84.0        1     0            0        0
# 3           7+   8.5    96.0        1     0            0        0
# 4          18+   8.8    97.0        1     0            1        0
#
#    Availability          Directors     Genres        Country Language  Runtime
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9301 entries, 0 to 20965
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9301 non-null   int64
#  1   ID            9301 non-null   int64
#  2   Title         9301 non-null   object
#  3   Year          9301 non-null   int64
#  4   Age of Movie  9301 non-null   int64
#  5   Age Category  9301 non-null   object
#  6   IMDb          9301 non-null   float64
#  7   Rotten        9301 non-null   float64
#  8   Netflix       9301 non-null   int64
#  9   Hulu          9301 non-null   int64
#  10  Prime Video   9301 non-null   int64
#  11  Disney+       9301 non-null   int64
#  12  Availability  9301 non-null   int64
#  13  Directors     9301 non-null   object
#  14  Genres        9301 non-null   object
#  15  Country       9301 non-null   object
#  16  Language      9301 non-null   object
#  17  Runtime       9301 non-null   float64
# ...

# %%
df1.to_csv("Final-CLEAN-Dataset.csv")
