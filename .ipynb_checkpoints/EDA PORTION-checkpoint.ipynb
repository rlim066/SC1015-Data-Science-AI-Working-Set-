# %%
import requests as r
import numpy as np
import pandas as pd
import json

import seaborn as sb
import matplotlib.pyplot as plt 
sb.set() # set the default Seaborn style for graphics

# %%
moviedata = pd.read_csv('Final-CLEAN-Dataset.csv')

# %%
# Quantile 25% and 75%
Q1 = moviedata['Runtime'].quantile(0.25)
Q3 = moviedata['Runtime'].quantile(0.75)

#Interquartile range (IQR)
IQR = Q3 - Q1

# %%
moviedata = moviedata.drop(moviedata[(moviedata['Runtime'] <= Q1 - 1.5*IQR) | (moviedata['Runtime'] >= Q3 + 1.5*IQR)].index)
moviedata
# Out:
#         ID                              Title Decade  Age  IMDb  Rotten  \
# 3        4                 Back to the Future  1980s   7+   8.5      96
# 5        6  Spider-Man: Into the Spider-Verse  2010s   7+   8.4      97
# 8        9            Raiders of the Lost Ark  1980s   7+   8.4      95
# 10      11                        Taxi Driver  1970s  18+   8.3      95
# 12      13                    Pan's Labyrinth  2000s  18+   8.2      95
# ...    ...                                ...    ...  ...   ...     ...
# 9288  9289                       Own the Room  2020s   7+   6.4      46
# 9289  9290        Unidentified Flying Oddball  1970s  all   5.2      45
# 9291  9292                    'Twas the Night  2000s  all   5.3      45
# 9296  9297  The Story of the Animated Drawing  1950s  all   7.6      41
# 9298  9299                  The Liberty Story  1950s  all   7.4      40
#
#       Availability Score            Directors       Genres        Country  \
# 3                      1      Robert Zemeckis    Adventure  United States
# 5                      1      Bob Persichetti    Animation  United States
# 8                      1     Steven Spielberg       Action  United States
# 10                     1      Martin Scorsese        Crime  United States
# 12                     1   Guillermo del Toro        Drama         Mexico
# ...                  ...                  ...          ...            ...
# 9288                   1  Cristina Costantini  Documentary  United States
# 9289                   1        Russ Mayberry    Adventure  United States
# 9291                   1          Nick Castle       Comedy  United States
# 9296                   1     William Beaudine    Adventure  United States
# 9298                   1       Hamilton Luske    Adventure  United States
#
#      Language  Runtime
# 3     English      116
# 5     English      117
# 8     English      115
# 10    English      114
# 12    Spanish      118
# ...       ...      ...
# 9288  English       91
# 9289  English       93
# 9291  English       84
# 9296  English       60
# 9298  English       60
#
# [8469 rows x 12 columns]

# %%
moviedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8469 entries, 3 to 9298
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8469 non-null   int64
#  1   Title               8469 non-null   object
#  2   Decade              8469 non-null   object
#  3   Age                 8469 non-null   object
#  4   IMDb                8469 non-null   float64
#  5   Rotten              8469 non-null   int64
#  6   Availability Score  8469 non-null   int64
#  7   Directors           8469 non-null   object
#  8   Genres              8469 non-null   object
#  9   Country             8469 non-null   object
#  10  Language            8469 non-null   object
#  11  Runtime             8469 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 860.1+ KB

# %% [markdown]
# ## Numeric Variables

# %%
EDA_numeric = ["IMDb", "Rotten", "Runtime"]

# %%
moviedata[EDA_numeric].describe()
# Out:
#               IMDb       Rotten      Runtime
# count  8469.000000  8469.000000  8469.000000
# mean      5.810521    36.054080    96.874601
# std       1.282421    33.944482    13.978300
# min       1.000000     0.000000    60.000000
# 25%       5.000000     0.000000    88.000000
# 50%       6.000000    40.000000    95.000000
# 75%       6.700000    65.000000   105.000000
# max       9.000000   100.000000   135.000000

# %%
# Reindex the dataframe
index = []
for i in range(0, len(moviedata)):
    index.append(i)

moviedata = moviedata[EDA_numeric].reindex(index)

# %%
# Draw boxplot, histplot and violinplot of IMDb, Rotten and Runtime
f, axes = plt.subplots(3, 3, figsize=(20, 20))

count = 0
for i in EDA_numeric:
    sb.boxplot(data = moviedata[i], orient = "h", ax = axes[count,0])
    sb.histplot(data = moviedata[i], ax = axes[count,1])
    sb.violinplot(data = moviedata[i], orient = "h", ax = axes[count,2])
    count += 1

# %% [markdown]
# ## Categorical Variables

# %%
EDA_categorical = ["Decade", "Age", "Availability Score", "Directors", "Genres", "Country", "Language"]

# %%
#for i in EDA_categorical:
 #   sb.catplot(y = i, data = EDA_categorical[i], kind = "count", height = 8)

# %%
a = moviedata[EDA_categorical]
sb.catplot(y = "Decade", data = a, kind = "count", height = 8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6808/4083979205.py in <module>
# ----> 1 a = moviedata[EDA_categorical]
#       2 sb.catplot(y = "Decade", data = a, kind = "count", height = 8)
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Decade', 'Age', 'Availability Score', 'Directors', 'Genres', 'Country',\n       'Language'],\n      dtype='object')] are in the [columns]"
